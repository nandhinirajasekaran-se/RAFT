# %%
import os
import re
import json
import nltk
import pdfplumber
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import sent_tokenize
from langchain.document_loaders import PyPDFLoader
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import PromptTemplate

nltk.download('punkt')
load_dotenv()

llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0.5)

chunking_prompt = PromptTemplate(
    input_variables=["text"],
    template="""
You are a document analyzer. Split the following insurance policy text into 2–5 coherent and self-contained chunks, each suitable for generating question-answer pairs. Each chunk should:
- Be logically grouped by topic (e.g., dental, drug, exclusions)
- Not exceed ~1000 characters
- Be returned as a JSON list: ["chunk1...", "chunk2...", ...]

Text:
{text}
"""
)

qa_prompt = PromptTemplate(
    input_variables=["chunk", "metadata"],
    template="""
    You are a JSON generator for question-answer pairs. Given the document chunk and metadata below, generate 2-3 QA pairs in valid JSON format. Output ONLY the JSON array.

    Chunk: {chunk}
    Metadata: {metadata}

    Example output:
    [{{"question": "What is the drug reimbursement rate?", "answer": "60% reimbursement"}},
     {{"question": "What is the annual maximum?", "answer": "$750"}}]
    """
)

def is_complex_chunk(text):
    return bool(re.search(r'exclusion|limitation|condition', text, re.IGNORECASE))

def generate_llm_qa(text, metadata):
    try:
        formatted_prompt = qa_prompt.format_prompt(
            chunk=text[:1000],
            metadata=json.dumps(metadata)
        ).to_string()

        response = llm([HumanMessage(content=formatted_prompt)]).content
        print("\n🧾 Raw LLM Output:\n", response)

        try:
            qa_list = json.loads(response)
        except:
            start, end = response.find("["), response.rfind("]") + 1
            qa_list = json.loads(response[start:end]) if start != -1 and end != -1 else []

        valid_qas = []
        for qa in qa_list:
            if isinstance(qa, dict) and "question" in qa and "answer" in qa:
                valid_qas.append(qa)
            else:
                print("⚠️ Skipping malformed QA:", repr(qa))
        return valid_qas
    except Exception as e:
        print("❌ LLM QA generation failed:", e)
        return []

def generate_template_qa(text, metadata):
    pattern = r'(\w+)\s+reimbursement|maximum of \$([\d,]+)'
    matches = re.findall(pattern, text)
    qa_pairs = []
    for m in matches:
        entity = m[0] or m[1]
        question = f"What is the {entity} reimbursement rate for the {metadata['plan_type']} plan?"
        qa_pairs.append({"question": question, "answer": text[:200]})
    return qa_pairs

from langchain_core.messages import HumanMessage

def llm_informed_chunk(text):
    prompt = chunking_prompt.format_prompt(text=text).to_string()
    try:
        response = llm([HumanMessage(content=prompt)]).content
        print("🧾 Raw chunking response:\n", response)

        # Extract JSON list from response
        try:
            chunks = json.loads(response)
        except json.JSONDecodeError:
            start = response.find("[")
            end = response.rfind("]") + 1
            chunks = json.loads(response[start:end]) if start != -1 and end != -1 else []

        # Final check
        return [chunk.strip() for chunk in chunks if isinstance(chunk, str) and len(chunk.strip()) > 100]
    except Exception as e:
        print("❌ LLM chunking failed:", e)
        return []


from langchain.document_loaders import PyPDFLoader

pdf_file = "phi-basic.pdf"
loader = PyPDFLoader(f"datastore/{pdf_file}")
pages = loader.load()

all_chunks = []
for page in pages:
    long_text = page.page_content.strip()
    page_chunks = llm_informed_chunk(long_text)
    all_chunks.extend(page_chunks)


qa_dataset = []
for chunk in all_chunks:
    metadata = {"source_file": pdf_file, "plan_type": "basic"}

    qa_pairs = generate_llm_qa(chunk, metadata) if is_complex_chunk(chunk) else generate_template_qa(chunk, metadata)

    for qa in qa_pairs:
        if isinstance(qa, dict) and "question" in qa and "answer" in qa:
            qa_dataset.append({
                "question": qa["question"],
                "answer": qa["answer"],
                "source_file": pdf_file,
                "plan_type": "basic"
            })
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nandhinirajasekaran/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 🧾 Raw chunking response:
#  [
#   "This insurance policy is for Personal Health Insurance with Basic coverage and Semi-Private Hospital accommodation under Series 9.01. The provided policy wording is incomplete and serves as a general reference only. Actual issued policies may contain additional provisions not reflected in this sample. Policy wording is subject to periodic changes, and the actual policy issued to a client will govern the relationship.",
#   "The information provided in this sample policy is not to be considered a contract or an offer to contract. It is important to note that the wording in the actual issued policy may differ from this sample. Clients should refer to their specific policy for accurate details and coverage information. Any discrepancies between this sample wording and the issued policy will be resolved in favor of the policy terms."
# ]
# 🧾 Raw chunking response:
#  [
#   "Chunk 1: Introduction and Definitions",
#   "Sun Life Assurance Company of Canada agrees to provide the benefits of this policy according to its terms and conditions. In this document, you and your mean the owner of this policy. We, us, our, and the company mean Sun Life Assurance Company of Canada. Sun Life Assurance Company of Canada is the insurer, and is a member of the Sun Life Financial group of companies. Signed at Waterloo, Ontario",
#   "Chunk 2: Important Notice and Policy Overview",
#   "It’s important that you read your entire policy carefully. It sets out the benefits payable and has exclusions and limitations. To help you understand insurance terms, refer to the explanations described under the heading, Insurance terms. THESE DOCUMENTS CONTAIN IMPORTANT INFORMATION ABOUT YOUR INSURANCE. PLEASE KEEP THEM IN A SAFE PLACE."
# ]
# 🧾 Raw chunking response:
#  [
#   "Policy Particulars: This section likely includes details such as policy number, effective date, coverage limits, and other key information about the insurance policy. It is essential for policyholders to review this section carefully to ensure they understand the specifics of their coverage.",
#   "Drug Provision: The drug provision section outlines the coverage related to prescription medications. It may include information about formularies, copayments, coverage limits, and any restrictions on specific medications. Understanding this section is crucial for individuals who rely on prescription drugs.",
#   "Semi-Private Hospital Room Provision: This section explains the coverage related to semi-private hospital rooms. It may include details about eligibility criteria, coverage limits, and any additional costs associated with choosing a semi-private room. Policyholders should review this section to understand their options during hospital stays.",
#   "Dental Provision: The dental provision section outlines the coverage related to dental care and treatments. It may include information about preventive services, restorative procedures, coverage limits, and any exclusions. Understanding this section is important for individuals seeking dental insurance benefits."
# ]
# 🧾 Raw chunking response:
#
# [
#   "Chunk 1: Policy Particulars",
#   "This document contains important information about your insurance. Please keep it in a safe place. Plan: Personal Health Insurance. Policy number: xxxx ID number: Owner (Insured person): First & Last Name. Additional insured person(s): First & Last Name. Effective date of your policy: MMMM d, yyyy.",
#   "Chunk 2: Payment Schedule",
#   "As the owner, you must pay all premiums and any applicable taxes for this policy by the payment due date. Payments are due monthly on the 1st day of the month, starting on January. Premium: $*. Provincial sales tax: $0.00. Total monthly payment: $*. Your premium is not guaranteed and may change with a 30-day written notice. An administrative fee may apply for returned payments.",
#   "Chunk 3: Important Information",
#   "The policy includes restricted benefits and has exclusions and limitations. It is important to read your policy carefully. The Policy Particulars page is included in and forms part of your policy, replacing any previous Policy Particulars page. The information is subject to the provisions, terms, and conditions of the policy."
# ]
# 🧾 Raw chunking response:
#  [
#   "Drug: The amount we pay for the dispensing fee reimbursement is 100% but is limited to a maximum of $5 per prescription. If you have prescription drug insurance through the Régie de l’assurance maladie du Québec (RAMQ), your claims must first be submitted to RAMQ. Any remaining unpaid portion eligible under this policy can then be submitted to us for reimbursement.",
#   "Drug: If you have group drug coverage and are not covered by RAMQ prescription drug insurance, your prescription drug claims must first be submitted to your group policy. Any remaining, unpaid portion eligible under this policy can then be submitted to us for reimbursement. Contact us to coordinate drug benefits between your group policy and this policy. If your group drug coverage ends, obtain RAMQ prescription drug insurance to remain eligible under this policy.",
#   "Dental: An insured person becomes eligible for preventive dental coverage three months after the effective date of this policy. The benefit reimbursement maximum per person for preventive dental coverage is 60% up to $500 in a calendar year. Optional benefits include semi-private hospital room coverage at 85%, described in the Semi-private hospital room provision section."
# ]
# 🧾 Raw chunking response:
#  [
#   "Chunk 1: Policy Cancellation within 10 Days of Receiving Policy",
#   "If you change your mind within 10 days of receiving your policy from us, you may send a written request to cancel it. Your policy is considered received 5 days after it's mailed from our office. Upon receiving your request, we'll refund any amount paid without interest, known as rescission.",
#   "Chunk 2: Policy Cancellation at Any Other Time",
#   "You have the right to cancel your policy at any time. Once we receive your cancellation request, all our obligations and liabilities under the policy end immediately. The cancellation is binding on you and any person entitled to make a claim under the policy.",
#   "Chunk 3: Process to Cancel Policy",
#   "To cancel your policy, send a written request to Sun Life Assurance Company of Canada at PO Box 1601, Stn Waterloo, Waterloo ON N2J 4C5.",
#   "Chunk 4: Nurse Practitioner Coverage",
#   "Reference to a physician may include a nurse practitioner. If provincial and territorial legislation allows nurse practitioners to prescribe certain supplies or services, we will reimburse those eligible services or supplies prescribed by a nurse practitioner as if prescribed by a physician."
# ]
# 🧾 Raw chunking response:
#  [
#   "Drug Provision: This plan covers prescription drugs with a Drug Identification Number (DIN). It includes drugs legally requiring a prescription, life-sustaining drugs, injectable drugs, compounded preparations with eligible active ingredients, diabetic supplies, and smoking cessation products up to $250 lifetime maximum per person. Payments are limited to a three-month supply.",
#   "Eligibility Criteria: Covered expenses are up to the specified limit and must be medically necessary, reasonable and customary charges, prescribed by an authorized medical professional, and dispensed by a registered pharmacist or physician. Generic substitution is allowed unless the prescriber specifies otherwise.",
#   "Exclusions: The policy does not cover drugs for infertility or sexual dysfunction, anti-obesity drugs, dietary supplements, infant formulas, contraceptives, injection costs, over-the-counter smoking cessation products, or expenses listed in the policy's exclusion section. Even if prescribed, these items are not reimbursable."
# ]
# 🧾 Raw chunking response:
#
# [
#     "Chunk 1: Extended Health Provision - Eligible Expenses",
#     "Chunk 2: Paramedical Practitioners and Coverage Limits",
#     "Chunk 3: Dental Surgeon Services and Limitations",
#     "Chunk 4: Ground Ambulance Services Coverage",
#     "Chunk 5: Emergency Air Ambulance Services Coverage"
# ]
# 🧾 Raw chunking response:
#  [
#   "Chunk 1: This chunk discusses the coverage for provincially funded services and equipment, as well as the conditions for payment without proof of government funding application. It includes coverage for artificial limbs, braces, oxygen, nurse services, home care services, walkers, wheelchairs, and repairs to durable medical equipment.",
#   "Chunk 2: This chunk outlines the coverage for specific medical equipment and services without the need for proof of government funding application. It includes coverage for continuous glucose monitor receivers, blood glucose monitors, diagnostic tests, orthopaedic shoes, casts, wigs, and hairpieces. It also mentions the reimbursement for repairs to durable medical equipment.",
#   "Chunk 3: This chunk specifies additional coverage for Quebec residents, including payment for MRI, CAT scans, CT scans, and ultrasounds. It then transitions to the exclusions section, listing items that will not be covered, such as those purchased solely for athletic use."
# ]
# 🧾 Raw chunking response:
#  [
#   "Dental provision: This section outlines the eligible expenses covered under the dental provision of the insurance policy. It specifies that expenses will be covered up to the limit specified on the Plan summary page. If an anticipated expense is not described as eligible, the insured person must contact the insurance provider before incurring the expense. Coverage includes dental procedures performed by licensed professionals and only reasonable expenses will be covered. The insurance provider may obtain a second opinion at the insured person's expense before a procedure is performed to verify appropriateness.",
#   "Exclusions: This section details what expenses will not be covered by the insurance policy. It specifies that expenses not medically necessary for the insured person's treatment, such as telephones or television rental charges, will not be covered. Additionally, expenses incurred under any conditions specified in the 'When we will not pay (exclusions)' section of the policy pages will not be covered. This ensures that only essential medical expenses are covered by the insurance policy."
# ]
# 🧾 Raw chunking response:
#  [
#   "Claims are paid based on eligible expenses, taking into account all limitations and exclusions. An expense is incurred on the date of the dental procedure. Temporary services are considered part of the final procedure. Final procedure fee determines usual charge for temporary service. Statement of treatment, x-rays, and additional info may be required for eligibility.",
#   "Covered dental procedures include preventive measures like examinations, x-rays, consultations, cleanings, fluoride treatments, and more. Services for children include space maintainers, sealants, and fillings. Removal of teeth, restorations, and scaling/root planing are also covered. Limits may apply to certain procedures."
# ]
# 🧾 Raw chunking response:
#  [
#     "Limitations: The amount payable for an eligible expense is limited to the least expensive treatment that produces a professionally adequate result. If a more expensive treatment is chosen, payment is limited to the lower cost of an alternative treatment determined by us. Payment may be based on charges for similar services if CDA procedure codes change or eligibility is unclear.",
#     "Exclusions: We do not pay for replacement of lost periodontal appliances, malocclusion or orthodontic treatment, services with surgical services under a government plan, full mouth reconstructions, congenital malformations, missed appointments, claim form completion charges, and expenses under specified conditions in the policy's exclusion section."
# ]
# 🧾 Raw chunking response:
#  [
#   "The insurance policy confirms the eligibility of expenses submitted by comparing them to limitations and exclusions. If an expense is not eligible, it is subtracted from the total claimed amount. The payment is based on the lowest of the claimed amount, customary charge, and maximum claimable amount.",
#   "To be eligible for coverage, a person must be a resident of Canada, covered under provincial or territorial health and drug insurance, and for Quebec residents, have coverage through a group benefit plan or RAMQ. Spouses must be legally recognized, and children must meet specific age and dependency criteria.",
#   "Children who become disabled before the age limit and remain disabled can still qualify for coverage if they are financially dependent and do not have a spouse. It is the policyholder's responsibility to inform the insurer if an insured person no longer meets the eligibility requirements.",
#   "Newborn children can be added to the policy without evidence within 30 days of their birth. Only one person can be covered as a spouse at a time. Proof of eligibility must be provided within six months of a child reaching the age limit."
# ]
# 🧾 Raw chunking response:
#  [
#   "Adding a child as an insured person requires proof of relationship and may require evidence of insurability for children aged 31 days or older. The child must meet specific criteria to be eligible, including being your child, under 21, or a disabled child dependent on you for financial support.",
#   "You can apply in writing to add an insured person or a child to your policy. The change takes effect upon approval or at the beginning of the next monthly coverage period. Adding other eligible persons requires meeting eligibility requirements and providing evidence of insurability.",
#   "You can request in writing to remove an insured person from the policy, with the change taking effect at the beginning of the next monthly coverage period. Coverage will end if eligibility requirements are not met, premiums are not paid, a written request to end coverage is received, or in case of death."
# ]
# 🧾 Raw chunking response:
#  [
#   "The emergency travel medical coverage provided by the policy ends at age 80. This limitation should be considered when planning for medical emergencies while traveling.",
#   "The contract between you and the insurance company consists of specific documents, including your application for insurance, the Policy particulars page, and the policy itself. It is important to keep these documents safe as they contain crucial information about your insurance coverage.",
#   "If the insurance company pays a benefit due to an illness, injury, or accident for which a third party may be responsible, they have the right to seek reimbursement. This subrogation process ensures that the insurance company is reimbursed for the benefits paid out.",
#   "All monetary amounts mentioned in the policy are in Canadian dollars. Premiums are due on the date specified on the Policy particulars page and may vary based on the insured person's age and province of residence. The insurance company reserves the right to adjust premiums based on various factors, including claims experience and expenses."
# ]
# 🧾 Raw chunking response:
#  [
#   "Premium Changes and Grace Period: If there is a change in your premium, you will receive a 30-day written notice. A grace period of 31 days is allowed for premium payments, except the first. During this period, insurance remains in force, but termination occurs if payment is not made. Claims after termination are not eligible.",
#   "Right to Copies of Documents: You or a claimant can request copies of your insurance application and any other evidence of insurability provided. The first copy is free, but subsequent copies may incur a fee.",
#   "Coordination of Benefits: Coverage is provided on a second payer basis. Benefits from similar plans or insurance policies must be coordinated to avoid exceeding eligible expenses incurred. This includes government health and drug insurance plans, automobile insurance plans, and third party liability insurance.",
#   "Integration with Government Programs: This policy will integrate with benefits available under government-sponsored plans. Covered expenses are those not payable or available under the government program, regardless of application status or coverage impact on eligibility. Waiting lists are also considered.",
#   "Exclusions: Payment will not be made for services not legally allowed, cosmetic items, experimental services, delivery charges, self-prescribed items, or services provided by a resident in the insured person's home or a relative by blood or marriage."
# ]
# 🧾 Raw chunking response:
#
# [
#     "Chunk 1: Exclusions related to government-sponsored plans or programs, unapproved services or supplies, and experimental treatments. This includes expenses not approved by Health Canada, treatments not typically used for illnesses, and treatments not meeting medical expense criteria under the Income Tax Act.",
#     "Chunk 2: Exclusions for elective medical treatments or surgeries performed outside the insured person's province. The policy does not cover non-emergency medical procedures conducted in a different province than where the insured person resides.",
#     "Chunk 3: Exclusions for illnesses resulting from specific circumstances, such as hostile actions by armed forces, participation in insurrections, riots, civil commotions, or criminal offenses. Benefits will not be paid for illnesses arising from these prohibited activities."
# ]
# 🧾 Raw chunking response:
#  [
#   "Chunk 1: Dental Coverage",
#   "The dental fee guide referenced in this policy is the current fee guide approved by the dental association in the province where the expense was incurred. If no guide is available for a given year, an adjusted fee guide established by the insurer will be used. A dentist is defined as a person licensed to practice dentistry by the provincial or territorial licensing authority.",
#   "Chunk 2: Policy Details",
#   "The effective date of coverage is the date specified on the Policy Particulars page. An emergency is defined as a sudden, unexpected occurrence of acute illness or accidental injury requiring immediate, medically necessary treatment prescribed by a physician. Evidence of insurability is written proof that a proposed insured person meets the underwriting requirements of the insurer.",
#   "Chunk 3: Hospital Coverage",
#   "A hospital, as defined in this policy, is a licensed facility that provides care and treatment for sick or injured patients. It must have diagnostic and treatment facilities, as well as 24-hour nursing care. The term 'hospital' excludes certain types of facilities like nursing homes, rest homes, and facilities for treating alcohol or drug abuse. The insurer sets limits on the maximum amount they will pay for each insured person over the lifetime of the policy."
# ]
# 🧾 Raw chunking response:
#  [
#   "Paramedical practitioners must meet specific qualifications to be considered qualified. This includes being a member of a governing body or an approved association, being licensed or registered as required, having appropriate training and credentials, maintaining clinical records, and more. The insurer has the discretion to determine if a practitioner meets these qualifications.",
#   "The policy defines a physician as a doctor of medicine (M.D.) licensed to practice. It also explains the concept of a policy anniversary as the same month and day each year as the policy's effective date. Additionally, it outlines the criteria for reasonable and customary charges for dental professional fees, health expenses, and dental laboratory charges, ensuring they are in line with standard practices and fees in the area."
# ]
# 🧾 Raw chunking response:
#  [
#   "Statutory conditions: The contract includes the application, policy, attached documents, and any agreed-upon amendments after issuance. No agent can change or waive provisions without written agreement. Waivers must be in writing, except for residents of specific provinces.",
#   "Termination of insurance: The contract can be terminated by the insurer with notice or by the insured upon request. Refunds are issued based on excess premium paid. The termination notice must include the refund. Timeframes for termination start after delivery of the notice to the insured.",
#   "Material facts: Statements made by the insured at the time of application cannot be used to defend a claim or avoid the contract unless included in the application or written evidence of insurability.",
#   "Notice and proof of claim: Written notice of a claim must be given to the insurer within 30 days of the claim arising. It can be delivered in person, sent by registered mail, or given to an authorized agent of the insurer."
# ]
# 🧾 Raw chunking response:
#  [
#   "Chunk 1: Proof of Claim Requirements",
#   "Under the insurance policy, the claimant must provide proof of an accident, sickness, or disability within 90 days of the claim arising. This proof includes details of the incident, the resulting loss, the right to payment, and relevant ages. Additionally, the insurer may request a certificate detailing the cause or nature of the claim, as well as the duration of any sickness or disability.",
#   "Chunk 2: Failure to Give Notice or Proof",
#   "Failure to provide notice of a claim or proof within the specified time frame does not necessarily invalidate the claim. Residents of Saskatchewan must provide notice or proof as soon as reasonably possible, within the limitation period set out in The Limitations Act. Residents of other provinces have up to one year to provide notice or proof, with exceptions for cases involving the death of the insured.",
#   "Chunk 3: Insurer's Responsibilities",
#   "The insurer is required to provide claim forms within 15 days of receiving notice of a claim. If the forms are not received within this timeframe, the claimant may submit a written statement detailing the accident, sickness, or disability and the resulting loss. Additionally, the insurer has the right to examine the person insured, including the option of requesting an autopsy in the event of death, subject to applicable laws.",
# ]
# ❌ LLM chunking failed: Expecting value: line 8 column 1 (char 1379)
# 🧾 Raw chunking response:
#  [
#   "Residents of Saskatchewan are entitled to have the insurer cover the costs of any examination or autopsy, with copies of reports provided to the insured or their representative.",
#   "All money payable under the insurance contract, excluding benefits for loss of time, must be paid by the insurer within 60 days of receiving proof of claim.",
#   "In Ontario, any action or proceeding against the insurer for the recovery of insurance money must be commenced within the time specified in the Limitations Act, 2002.",
#   "In provinces or territories other than Ontario, any action or proceeding against the insurer for the recovery of insurance money must be commenced within the time specified in the Insurance Act or other applicable legislation."
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "Who is responsible for providing the benefits of this policy?", "answer": "Sun Life Assurance Company of Canada"},
#     {"question": "What do 'you' and 'your' refer to in this document?", "answer": "The owner of this policy"},
#     {"question": "Where was the document signed?", "answer": "Waterloo, Ontario"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "Why is it important to read the entire policy carefully?", "answer": "It sets out the benefits payable and has exclusions and limitations."},
#     {"question": "Where can you find explanations for insurance terms?", "answer": "Under the heading, Insurance terms."},
#     {"question": "What should you do with these documents?", "answer": "Keep them in a safe place."}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What does the dental provision section outline?", "answer": "The coverage related to dental care and treatments."},
#     {"question": "Why is understanding the dental provision section important?", "answer": "It is important for individuals seeking dental insurance benefits."},
#     {"question": "What information may be included in the dental provision section?", "answer": "Information about preventive services, restorative procedures, coverage limits, and any exclusions."}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What does the policy include?", "answer": "Restricted benefits and exclusions and limitations"},
#     {"question": "What should policyholders do?", "answer": "Read the policy carefully"},
#     {"question": "What is included in the Policy Particulars page?", "answer": "It forms part of the policy, replacing any previous Policy Particulars page"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What types of drugs are not covered by the policy?", "answer": "Drugs for infertility, sexual dysfunction, anti-obesity, dietary supplements, infant formulas, contraceptives, smoking cessation products"},
#     {"question": "Are injection costs covered by the policy?", "answer": "No, injection costs are not covered"},
#     {"question": "What items are listed in the policy's exclusion section?", "answer": "Expenses not covered by the policy"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What services and equipment are covered by provincially funded services?", "answer": "Artificial limbs, braces, oxygen, nurse services, home care services, walkers, wheelchairs, and repairs to durable medical equipment"},
#     {"question": "Are there conditions for payment without proof of government funding application?", "answer": "Yes, there are conditions for payment without proof of government funding application"},
#     {"question": "What does the coverage include?", "answer": "The coverage includes artificial limbs, braces, oxygen, nurse services, home care services, walkers, wheelchairs, and repairs to durable medical equipment"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What additional coverage is specified for Quebec residents?", "answer": "Payment for MRI, CAT scans, CT scans, and ultrasounds"},
#     {"question": "What items are listed in the exclusions section as not covered?", "answer": "Items purchased solely for athletic use"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What does the 'Exclusions' section of the insurance policy detail?", "answer": "What expenses will not be covered"},
#     {"question": "Give an example of expenses not covered by the insurance policy.", "answer": "Telephones or television rental charges"},
#     {"question": "Why are expenses incurred under specified conditions not covered by the insurance policy?", "answer": "To ensure only essential medical expenses are covered"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {
#         "question": "How are claims paid?",
#         "answer": "Claims are paid based on eligible expenses, taking into account all limitations and exclusions."
#     },
#     {
#         "question": "When is an expense considered incurred?",
#         "answer": "An expense is incurred on the date of the dental procedure."
#     },
#     {
#         "question": "What determines the usual charge for temporary service?",
#         "answer": "Final procedure fee determines usual charge for temporary service."
#     }
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What is the limitation on the amount payable for an eligible expense?", "answer": "The least expensive treatment that produces a professionally adequate result"},
#     {"question": "How is payment limited if a more expensive treatment is chosen?", "answer": "Payment is limited to the lower cost of an alternative treatment determined by us"},
#     {"question": "On what basis may payment be made if CDA procedure codes change or eligibility is unclear?", "answer": "Payment may be based on charges for similar services"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What services are not covered under the basic plan?", "answer": "Replacement of lost periodontal appliances, malocclusion or orthodontic treatment, services with surgical services under a government plan, full mouth reconstructions, congenital malformations, missed appointments, claim form completion charges, and expenses under specified conditions"},
#     {"question": "What is excluded from coverage for congenital malformations?", "answer": "Congenital malformations are excluded from coverage"},
#     {"question": "Where can I find more details on the specified conditions in the policy's exclusion section?", "answer": "More details can be found in the policy's exclusion section"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {
#         "question": "How does the insurance policy determine the eligibility of expenses?",
#         "answer": "By comparing them to limitations and exclusions."
#     },
#     {
#         "question": "What happens if an expense is not eligible?",
#         "answer": "It is subtracted from the total claimed amount."
#     },
#     {
#         "question": "On what basis is the payment calculated?",
#         "answer": "Based on the lowest of the claimed amount, customary charge, and maximum claimable amount."
#     }
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "At what age does the emergency travel medical coverage provided by the policy end?", "answer": "Age 80"},
#     {"question": "What should be considered when planning for medical emergencies while traveling?", "answer": "The limitation of coverage ending at age 80"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What services are excluded from payment?", "answer": "Services not legally allowed, cosmetic items, experimental services, delivery charges, self-prescribed items, services provided by a resident in the insured person's home or a relative by blood or marriage"},
#     {"question": "What is the source file for this information?", "answer": "phi-basic.pdf"},
#     {"question": "What type of plan is this?", "answer": "basic"}
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What types of exclusions are related to government-sponsored plans or programs?", "answer": "Exclusions related to government-sponsored plans or programs include unapproved services or supplies, and experimental treatments."},
#     {"question": "What expenses are not approved by Health Canada?", "answer": "Expenses not approved by Health Canada are excluded."},
#     {"question": "What criteria do treatments need to meet under the Income Tax Act to be covered?", "answer": "Treatments need to meet medical expense criteria under the Income Tax Act to be covered."}
# ]
#
# 🧾 Raw LLM Output:
#
# [
#     {
#         "question": "What types of medical treatments or surgeries are excluded if performed outside the insured person's province?",
#         "answer": "Elective medical treatments or surgeries"
#     },
#     {
#         "question": "Does the policy cover non-emergency medical procedures conducted in a different province than where the insured person resides?",
#         "answer": "No, it does not cover them"
#     }
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "What specific circumstances are excluded from illnesses coverage?", "answer": "Hostile actions by armed forces, participation in insurrections, riots, civil commotions, or criminal offenses"},
#     {"question": "What benefits will not be paid for illnesses arising from prohibited activities?", "answer": "Benefits will not be paid"},
#     {"question": "What is the source file of this document?", "answer": "phi-basic.pdf"}
# ]
#
# 🧾 Raw LLM Output:
#
# [
#     {
#         "question": "What is included in the contract?",
#         "answer": "The contract includes the application, policy, attached documents, and any agreed-upon amendments after issuance."
#     },
#     {
#         "question": "Can an agent change or waive provisions without written agreement?",
#         "answer": "No, no agent can change or waive provisions without written agreement."
#     },
#     {
#         "question": "Are waivers required to be in writing?",
#         "answer": "Yes, waivers must be in writing, except for residents of specific provinces."
#     }
# ]
#
# 🧾 Raw LLM Output:
#  [
#     {"question": "In Ontario, what is the time frame specified for commencing any action or proceeding against the insurer for the recovery of insurance money?", "answer": "The time specified in the Limitations Act, 2002"},
#     {"question": "What must be done within the specified time frame in Ontario for the recovery of insurance money from the insurer?", "answer": "Commencing any action or proceeding"},
#     {"question": "What is the metadata information for this document chunk?", "answer": "Source file: phi-basic.pdf, Plan type: basic"}
# ]

# %%
with open("raft_qa_dataset_llm_chunked.json", "w") as f:
    json.dump(qa_dataset, f, indent=2)

print(f"✅ Saved {len(qa_dataset)} QA pairs using LLM-Informed Chunking.")
# Out:
# ✅ Saved 61 QA pairs using LLM-Informed Chunking.
